# %% [markdown]
# ### Establishing a connection between highest paid developers vs lowest

# %%
import pandas as pd
df = pd.read_csv('developer_survey_2020/survey_results_public.csv', index_col='Respondent')
schema_df = pd.read_csv('developer_survey_2020/survey_results_schema.csv', index_col='Column')

# %%
pd.set_option('display.max_columns', 61)
pd.set_option('display.max_rows', 61)

# %%
df.head(3)
# Out:
#                                 MainBranch Hobbyist  Age Age1stCode CompFreq  \
# Respondent
# 1           I am a developer by profession      Yes  NaN         13  Monthly
# 2           I am a developer by profession       No  NaN         19      NaN
# 3              I code primarily as a hobby      Yes  NaN         15      NaN
#
#             CompTotal  ConvertedComp             Country    CurrencyDesc  \
# Respondent
# 1                 NaN            NaN             Germany   European Euro
# 2                 NaN            NaN      United Kingdom  Pound sterling
# 3                 NaN            NaN  Russian Federation             NaN
#
#            CurrencySymbol DatabaseDesireNextYear  \
# Respondent
# 1                     EUR   Microsoft SQL Server
# 2                     GBP                    NaN
# 3                     NaN                    NaN
#
#                                    DatabaseWorkedWith  \
# Respondent
# ...

# %%
df['Age1stCode'].fillna(0)
# Out:
# Respondent
# 1        13
# 2        19
# 3        15
# 4        18
# 5        16
#          ..
# 64858    16
# 64867     0
# 64898     0
# 64925     0
# 65112     0
# Name: Age1stCode, Length: 64461, dtype: object

# %%
filt = df['LanguageWorkedWith'].str.contains('Python', na=False)

# %%
df.loc[filt, 'LanguageWorkedWith']
# Out:
# Respondent
# 3                                 Objective-C;Python;Swift
# 8                                               Python;SQL
# 10                     HTML/CSS;Java;JavaScript;Python;SQL
# 13                                     C;JavaScript;Python
# 15        Bash/Shell/PowerShell;C;HTML/CSS;Java;Python;SQL
#                                ...
# 61561    Bash/Shell/PowerShell;HTML/CSS;JavaScript;Perl...
# 62391       C++;HTML/CSS;JavaScript;Python;Ruby;TypeScript
# 63077              C++;HTML/CSS;Java;JavaScript;Python;SQL
# 63640    Bash/Shell/PowerShell;C;C#;C++;HTML/CSS;Java;J...
# 64867    Assembly;Bash/Shell/PowerShell;C;C#;C++;Dart;G...
# Name: LanguageWorkedWith, Length: 25287, dtype: object

# %%
df.columns =  [x.lower() for x in df.columns]
df.head(2)
# Out:
#                                 mainbranch hobbyist  age age1stcode compfreq  \
# Respondent
# 1           I am a developer by profession      Yes  NaN         13  Monthly
# 2           I am a developer by profession       No  NaN         19      NaN
#
#             comptotal  convertedcomp         country    currencydesc  \
# Respondent
# 1                 NaN            NaN         Germany   European Euro
# 2                 NaN            NaN  United Kingdom  Pound sterling
#
#            currencysymbol databasedesirenextyear  \
# Respondent
# 1                     EUR   Microsoft SQL Server
# 2                     GBP                    NaN
#
#                                    databaseworkedwith  \
# Respondent
# 1           Elasticsearch;Microsoft SQL Server;Oracle
# 2                                                 NaN
#
#                                                       devtype  \
# Respondent
# 1           Developer, desktop or enterprise applications;...
# ...

# %%
df.rename(columns={'mainbranch': 'MAINbranch'}, inplace=True)
df.head(2)
# Out:
#                                 MAINbranch hobbyist  age age1stcode compfreq  \
# Respondent
# 1           I am a developer by profession      Yes  NaN         13  Monthly
# 2           I am a developer by profession       No  NaN         19      NaN
#
#             comptotal  convertedcomp         country    currencydesc  \
# Respondent
# 1                 NaN            NaN         Germany   European Euro
# 2                 NaN            NaN  United Kingdom  Pound sterling
#
#            currencysymbol databasedesirenextyear  \
# Respondent
# 1                     EUR   Microsoft SQL Server
# 2                     GBP                    NaN
#
#                                    databaseworkedwith  \
# Respondent
# 1           Elasticsearch;Microsoft SQL Server;Oracle
# 2                                                 NaN
#
#                                                       devtype  \
# Respondent
# 1           Developer, desktop or enterprise applications;...
# ...

# %%
df.loc[2, ['MAINbranch', 'age', 'age1stcode']] = ['Im a DEVELOPER by profession', 22, 15]

# %%
df.head(2)
# Out:
#                                 MAINbranch hobbyist   age age1stcode compfreq  \
# Respondent
# 1           I am a developer by profession      Yes   NaN         13  Monthly
# 2             Im a DEVELOPER by profession       No  22.0         15      NaN
#
#             comptotal  convertedcomp         country    currencydesc  \
# Respondent
# 1                 NaN            NaN         Germany   European Euro
# 2                 NaN            NaN  United Kingdom  Pound sterling
#
#            currencysymbol databasedesirenextyear  \
# Respondent
# 1                     EUR   Microsoft SQL Server
# 2                     GBP                    NaN
#
#                                    databaseworkedwith  \
# Respondent
# 1           Elasticsearch;Microsoft SQL Server;Oracle
# 2                                                 NaN
#
#                                                       devtype  \
# Respondent
# 1           Developer, desktop or enterprise applications;...
# ...

# %%
df.loc[2, 'age'] == int(55)
df.head()
# Out:
#                                                    MAINbranch hobbyist   age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                                Im a DEVELOPER by profession       No  22.0
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
#
#            age1stcode compfreq  comptotal  convertedcomp             country  \
# Respondent
# 1                  13  Monthly        NaN            NaN             Germany
# 2                  15      NaN        NaN            NaN      United Kingdom
# 3                  15      NaN        NaN            NaN  Russian Federation
# 4                  18      NaN        NaN            NaN             Albania
# 5                  16      NaN        NaN            NaN       United States
#
# ...

# %%
df.loc[2, 'age'] = 33
df.loc[1, 'age'] = 44

# %%
df.head(3)
# Out:
#                                 MAINbranch hobbyist   age age1stcode compfreq  \
# Respondent
# 1           I am a developer by profession      Yes  44.0         13  Monthly
# 2             Im a DEVELOPER by profession       No  33.0         15      NaN
# 3              I code primarily as a hobby      Yes   NaN         15      NaN
#
#             comptotal  convertedcomp             country    currencydesc  \
# Respondent
# 1                 NaN            NaN             Germany   European Euro
# 2                 NaN            NaN      United Kingdom  Pound sterling
# 3                 NaN            NaN  Russian Federation             NaN
#
#            currencysymbol databasedesirenextyear  \
# Respondent
# 1                     EUR   Microsoft SQL Server
# 2                     GBP                    NaN
# 3                     NaN                    NaN
#
#                                    databaseworkedwith  \
# Respondent
# ...

# %%
filt = (df['country'] == 'Germany')
df.loc[filt, 'currencysymbol'] = 'USD'
df.head(2)
# Out:
#                                 MAINbranch hobbyist   age age1stcode compfreq  \
# Respondent
# 1           I am a developer by profession      Yes  44.0         13  Monthly
# 2             Im a DEVELOPER by profession       No  33.0         15      NaN
#
#             comptotal  convertedcomp         country    currencydesc  \
# Respondent
# 1                 NaN            NaN         Germany   European Euro
# 2                 NaN            NaN  United Kingdom  Pound sterling
#
#            currencysymbol databasedesirenextyear  \
# Respondent
# 1                     USD   Microsoft SQL Server
# 2                     GBP                    NaN
#
#                                    databaseworkedwith  \
# Respondent
# 1           Elasticsearch;Microsoft SQL Server;Oracle
# 2                                                 NaN
#
#                                                       devtype  \
# Respondent
# 1           Developer, desktop or enterprise applications;...
# ...

# %%
df.rename(columns={'age1stcode': 'Learned to code at age:'}, inplace=True)

# %%
df.head(2)
# Out:
#                                 MAINbranch hobbyist   age  \
# Respondent
# 1           I am a developer by profession      Yes  44.0
# 2             Im a DEVELOPER by profession       No  33.0
#
#            Learned to code at age: compfreq  comptotal  convertedcomp  \
# Respondent
# 1                               13  Monthly        NaN            NaN
# 2                               15      NaN        NaN            NaN
#
#                    country    currencydesc currencysymbol  \
# Respondent
# 1                  Germany   European Euro            USD
# 2           United Kingdom  Pound sterling            GBP
#
#            databasedesirenextyear                         databaseworkedwith  \
# Respondent
# 1            Microsoft SQL Server  Elasticsearch;Microsoft SQL Server;Oracle
# 2                             NaN                                        NaN
#
#                                                       devtype  \
# Respondent
# ...

# %%
filt = (df['Learned to code at age:'] == '13')
df[filt]
# Out:
#                                         MAINbranch hobbyist   age  \
# Respondent
# 1                   I am a developer by profession      Yes  44.0
# 11                  I am a developer by profession      Yes  23.0
# 14                  I am a developer by profession      Yes  27.0
# 15          I am a student who is learning to code      Yes   NaN
# 35          I am a student who is learning to code      Yes  16.0
# ...                                            ...      ...   ...
# 909                                            NaN      Yes   NaN
# 5646                                           NaN      Yes  25.0
# 18085                                          NaN      Yes  28.0
# 18853                                          NaN      Yes  19.0
# 27814                                          NaN      Yes   NaN
#
#            Learned to code at age: compfreq  comptotal  convertedcomp  \
# Respondent
# 1                               13  Monthly        NaN            NaN
# ...

# %%
df['hobbyist'] = df['hobbyist'].map({'Yes': True, 'No': False})

# %%
df.head(2)
# Out:
#                                 MAINbranch hobbyist   age  \
# Respondent
# 1           I am a developer by profession     True  44.0
# 2             Im a DEVELOPER by profession    False  33.0
#
#            Learned to code at age: compfreq  comptotal  convertedcomp  \
# Respondent
# 1                               13  Monthly        NaN            NaN
# 2                               15      NaN        NaN            NaN
#
#                    country    currencydesc currencysymbol  \
# Respondent
# 1                  Germany   European Euro            USD
# 2           United Kingdom  Pound sterling            GBP
#
#            databasedesirenextyear                         databaseworkedwith  \
# Respondent
# 1            Microsoft SQL Server  Elasticsearch;Microsoft SQL Server;Oracle
# 2                             NaN                                        NaN
#
#                                                       devtype  \
# Respondent
# ...

# %% [markdown]
# ### Calculate missing values in each column

# %%
missing_data = df.isnull()

for column in missing_data.columns.values.tolist():
    print(column)
    print(missing_data[column].value_counts())
    print("")
# Out:
# age
# False    45448
# True     19013
# Name: age, dtype: int64
#
# Learned to code at age:
# False    57900
# True      6561
# Name: Learned to code at age:, dtype: int64
#
# compfreq
# False    40069
# True     24392
# Name: compfreq, dtype: int64
#
# comptotal
# False    34826
# True     29635
# Name: comptotal, dtype: int64
#
# convertedcomp
# False    34756
# True     29705
# Name: convertedcomp, dtype: int64
#
# country
# False    64072
# True       389
# Name: country, dtype: int64
#
# currencydesc
# False    45472
# True     18989
# Name: currencydesc, dtype: int64
#
# currencysymbol
# False    46465
# True     17996
# Name: currencysymbol, dtype: int64
#
# databasedesirenextyear
# False    44070
# True     20391
# Name: databasedesirenextyear, dtype: int64
#
# databaseworkedwith
# False    49537
# True     14924
# Name: databaseworkedwith, dtype: int64
#
# devtype
# False    49370
# True     15091
# Name: devtype, dtype: int64
#
# edlevel
# False    57431
# True      7030
# ...

# %% [markdown]
# ### calculate the average of the column:

# %%
avg_column = df['yearscode'].astype('float').mean(axis=0)
print('Average of column yearscode: ', avg_column)
# Out:
# Average of column yearscode:  12.709052770265584

# %% [markdown]
# ### replace the NaN of "yearscode" column with average from avg_column

# %%
df['yearscode'].replace(np.nan, avg_column, inplace=True)

# %%
df['yearscode'].isnull().sum()
# Out:
# 0

# %% [markdown]
# - There are no missing values in 'yearscode' anymore

# %% [markdown]
# ### Lets calculate the most common type in a samle non-integer column:

# %%
webframe_filt = df['webframeworkedwith'].value_counts().idxmax()

# %% [markdown]
# ### Lets replace the NaN values with the common type values for 'webframworkedwith' column

# %%
df['webframeworkedwith'].replace(np.nan, webframe_filt, inplace=True)

# %%
df['webframeworkedwith'].isnull().sum()
# Out:
# 0

# %%
df['webframeworkedwith'][57981]
# Out:
# 'ASP.NET Core;React.js'

# %%
df.head(2)
# Out:
#             age Learned to code at age: compfreq     comptotal  convertedcomp  \
# Respondent
# 62788       NaN                     NaN   Weekly  8.000000e+06      1000000.0
# 65381       NaN                       8   Weekly  8.740000e+09      1000000.0
#
#                 country    currencydesc currencysymbol databasedesirenextyear  \
# Respondent
# 62788       Afghanistan    Albanian lek            ALL                    NaN
# 65381       Afghanistan  Afghan afghani            AFN                    NaN
#
#            databaseworkedwith  \
# Respondent
# 62788                     NaN
# 65381                     NaN
#
#                                                       devtype  \
# Respondent
# 62788                                               Scientist
# 65381       Data or business analyst;Data scientist or mac...
#
#                                            edlevel  \
# Respondent
# 62788       I never completed any formal education
# ...

# %%
df['compfreq'] + ' ' + df['currencysymbol']
df.head(2)
# Out:
#                                 MAINbranch hobbyist   age  \
# Respondent
# 1           I am a developer by profession     True  44.0
# 2             Im a DEVELOPER by profession    False  33.0
#
#            Learned to code at age: compfreq  comptotal  convertedcomp  \
# Respondent
# 1                               13  Monthly        NaN            NaN
# 2                               15      NaN        NaN            NaN
#
#                    country    currencydesc currencysymbol  \
# Respondent
# 1                  Germany   European Euro            USD
# 2           United Kingdom  Pound sterling            GBP
#
#            databasedesirenextyear                         databaseworkedwith  \
# Respondent
# 1            Microsoft SQL Server  Elasticsearch;Microsoft SQL Server;Oracle
# 2                             NaN                                        NaN
#
#                                                       devtype  \
# Respondent
# ...

# %%
df.drop(columns=['MAINbranch', 'hobbyist'], inplace=True)
df.head(2)
# Out:
#              age Learned to code at age: compfreq  comptotal  convertedcomp  \
# Respondent
# 1           44.0                      13  Monthly        NaN            NaN
# 2           33.0                      15      NaN        NaN            NaN
#
#                    country    currencydesc currencysymbol  \
# Respondent
# 1                  Germany   European Euro            USD
# 2           United Kingdom  Pound sterling            GBP
#
#            databasedesirenextyear                         databaseworkedwith  \
# Respondent
# 1            Microsoft SQL Server  Elasticsearch;Microsoft SQL Server;Oracle
# 2                             NaN                                        NaN
#
#                                                       devtype  \
# Respondent
# 1           Developer, desktop or enterprise applications;...
# 2                     Developer, full-stack;Developer, mobile
#
#                                                     edlevel  \
# Respondent
# ...

# %%
df.append({'compfreq' : 'Paulius'}, ignore_index=True)
# Out:
#         age Learned to code at age: compfreq  comptotal  convertedcomp  \
# 0      44.0                      13  Monthly        NaN            NaN
# 1      33.0                      15      NaN        NaN            NaN
# 2       NaN                      15      NaN        NaN            NaN
# 3      25.0                      18      NaN        NaN            NaN
# 4      31.0                      16      NaN        NaN            NaN
# ...     ...                     ...      ...        ...            ...
# 64457   NaN                     NaN      NaN        NaN            NaN
# 64458   NaN                     NaN      NaN        NaN            NaN
# 64459   NaN                     NaN      NaN        NaN            NaN
# 64460   NaN                     NaN      NaN        NaN            NaN
# 64461   NaN                     NaN  Paulius        NaN            NaN
#
#                   country    currencydesc currencysymbol  \
# ...

# %%
people = {
    'name': ['Paulius','Sniega'],
    'last': ['Komskis', 'Komskiene'],
    'email': ['sss@one.com', 'www@one.com'],
    
}
df_p = pd.DataFrame(people)
df_p
# Out:
#       name       last        email
# 0  Paulius    Komskis  sss@one.com
# 1   Sniega  Komskiene  www@one.com

# %%
people2 = {
    'name': ['Kailis','Grybas'],
    'last': ['Stark', 'Coolio'],
    'email': ['111s@one.com', '22w@one.com'],
}
df_p2 = pd.DataFrame(people2)
df_p2
# Out:
#      name    last         email
# 0  Kailis   Stark  111s@one.com
# 1  Grybas  Coolio   22w@one.com

# %%
df_p.append(df_p2, ignore_index=True, sort=True)
# Out:
#           email       last     name
# 0   sss@one.com    Komskis  Paulius
# 1   www@one.com  Komskiene   Sniega
# 2  111s@one.com      Stark   Kailis
# 3   22w@one.com     Coolio   Grybas

# %%
df_big= df_p.append(df_p2, ignore_index=True, sort=True)

# %%
df_big
# Out:
#           email       last     name
# 0   sss@one.com    Komskis  Paulius
# 1   www@one.com  Komskiene   Sniega
# 2  111s@one.com      Stark   Kailis
# 3   22w@one.com     Coolio   Grybas

# %%
df_big.drop(2)
# Out:
#          email       last     name
# 0  sss@one.com    Komskis  Paulius
# 1  www@one.com  Komskiene   Sniega
# 3  22w@one.com     Coolio   Grybas

# %%
df_big.sort_values(by='name', ascending=False)
# Out:
#           email       last     name
# 1   www@one.com  Komskiene   Sniega
# 0   sss@one.com    Komskis  Paulius
# 2  111s@one.com      Stark   Kailis
# 3   22w@one.com     Coolio   Grybas

# %%
df_big.sort_values(by=['last', 'name'], ascending=False)
# Out:
#           email       last     name
# 2  111s@one.com      Stark   Kailis
# 0   sss@one.com    Komskis  Paulius
# 1   www@one.com  Komskiene   Sniega
# 3   22w@one.com     Coolio   Grybas

# %%
df_big.sort_values(by=['last', 'name'], ascending=[False, True], inplace=True)

# %%
df_big
# Out:
#           email       last     name
# 2  111s@one.com      Stark   Kailis
# 0   sss@one.com    Komskis  Paulius
# 1   www@one.com  Komskiene   Sniega
# 3   22w@one.com     Coolio   Grybas

# %%
df_big.sort_index()
# Out:
#           email       last     name
# 0   sss@one.com    Komskis  Paulius
# 1   www@one.com  Komskiene   Sniega
# 2  111s@one.com      Stark   Kailis
# 3   22w@one.com     Coolio   Grybas

# %%
df_big['last'].sort_values()
# Out:
# 3       Coolio
# 1    Komskiene
# 0      Komskis
# 2        Stark
# Name: last, dtype: object

# %%
df.sort_values(by=['country', 'convertedcomp'], ascending=[True, False], inplace=True)

# %%
df[['country', 'convertedcomp']].head(10)
# Out:
#                 country  convertedcomp
# Respondent
# 62788       Afghanistan      1000000.0
# 65381       Afghanistan      1000000.0
# 65456       Afghanistan      1000000.0
# 38672       Afghanistan       231192.0
# 28374       Afghanistan       130000.0
# 9839        Afghanistan        23328.0
# 63848       Afghanistan        23328.0
# 51862       Afghanistan        20950.0
# 51509       Afghanistan        20220.0
# 44484       Afghanistan        18660.0

# %%
df['convertedcomp'].nlargest(10)
# Out:
# Respondent
# 5725     2000000.0
# 54263    2000000.0
# 43430    2000000.0
# 59279    2000000.0
# 46711    2000000.0
# 123      2000000.0
# 125      2000000.0
# 193      2000000.0
# 665      2000000.0
# 699      2000000.0
# Name: convertedcomp, dtype: float64

# %%
df.nlargest(5, 'convertedcomp')
# Out:
#              age Learned to code at age: compfreq     comptotal  \
# Respondent
# 5725        26.0                      14  Monthly  1.800000e+05
# 54263       29.0                      10   Weekly  7.000000e+04
# 43430       33.0                      17  Monthly  1.710000e+05
# 59279        NaN                      12  Monthly  3.000000e+05
# 46711        NaN    Younger than 5 years   Yearly  1.000000e+56
#
#             convertedcomp  country          currencydesc currencysymbol  \
# Respondent
# 5725            2000000.0   Canada  United States dollar            USD
# 54263           2000000.0   Canada  United States dollar            USD
# 43430           2000000.0    Italy  United States dollar            USD
# 59279           2000000.0    Nepal  United States dollar            USD
# 46711           2000000.0  Nomadic  United States dollar            USD
#
#                                        databasedesirenextyear  \
# Respondent
# ...

# %%
df['convertedcomp'].median()
# Out:
# 54049.0

# %%
df['newonboardgood'].value_counts()
# Out:
# Yes                             20729
# No                              12655
# Onboarding? What onboarding?     9239
# Name: newonboardgood, dtype: int64

# %%
df['opsys'].value_counts()
# Out:
# Windows        27170
# Linux-based    14932
# MacOS          14075
# BSD               51
# Name: opsys, dtype: int64

# %%
schema_df.loc['OpSys']
# Out:
# QuestionText    What is the primary operating system in which ...
# Name: OpSys, dtype: object

# %%
df['opsys'].value_counts(normalize=True)
# Out:
# Windows        0.483211
# Linux-based    0.265562
# MacOS          0.250320
# BSD            0.000907
# Name: opsys, dtype: float64

# %%
df['country'].value_counts()
# Out:
# United States       12469
# India                8403
# United Kingdom       3896
# Germany              3890
# Canada               2191
#                     ...
# Liechtenstein           1
# Grenada                 1
# Mali                    1
# Marshall Islands        1
# Chad                    1
# Name: country, Length: 183, dtype: int64

# %%
country_grp = df.groupby(['country'])

# %%
country_grp.get_group('Russian Federation')
# Out:
#              age Learned to code at age: compfreq  comptotal  convertedcomp  \
# Respondent
# 43095        NaN                      16  Monthly    80000.0      1000000.0
# 59380        NaN                      16  Monthly  6000000.0      1000000.0
# 59214       27.0                      12  Monthly    70000.0       908028.0
# 26383       35.0                      12  Monthly    48000.0       576000.0
# 10235       33.0                      13  Monthly   750000.0       141552.0
# ...          ...                     ...      ...        ...            ...
# 65275        NaN                     NaN      NaN        NaN            NaN
# 65324        NaN                      24  Monthly        NaN            NaN
# 65568        NaN                     NaN      NaN        NaN            NaN
# 58808        NaN                     NaN      NaN        NaN            NaN
# 63452        NaN                     NaN      NaN        NaN            NaN
#
# ...

# %%
filt = df['country'] == 'Russian Federation'
df.loc[filt]['opsys'].value_counts()
# Out:
# Windows        471
# Linux-based    293
# MacOS          192
# BSD              3
# Name: opsys, dtype: int64

# %%
country_grp['opsys'].value_counts(normalize=True).loc['China']
# Out:
# opsys
# Windows        0.539007
# MacOS          0.230496
# Linux-based    0.226950
# BSD            0.003546
# Name: opsys, dtype: float64

# %%
country_grp['convertedcomp'].median().loc['Germany']
# Out:
# 62697.0

# %%
country_grp['convertedcomp'].agg(['median', 'mean']).loc['United States']
# Out:
# median    115000.000000
# mean      208826.496443
# Name: United States, dtype: float64

# %%
filt = df['country'] == 'United States'
df.loc[filt]['languageworkedwith'].str.contains('Python').sum()
# Out:
# 5964

# %%
country_grp['languageworkedwith'].apply(lambda x: x.str.contains('Python').sum())
# Out:
# country
# Afghanistan                              11
# Albania                                  13
# Algeria                                  40
# Andorra                                   3
# Angola                                    1
#                                        ...
# Venezuela, Bolivarian Republic of...     29
# Viet Nam                                102
# Yemen                                     1
# Zambia                                    4
# Zimbabwe                                 13
# Name: languageworkedwith, Length: 183, dtype: int64

# %%
uses_python = country_grp['languageworkedwith'].apply(lambda x: x.str.contains('Python').sum())
uses_python
# Out:
# country
# Afghanistan                              11
# Albania                                  13
# Algeria                                  40
# Andorra                                   3
# Angola                                    1
#                                        ...
# Venezuela, Bolivarian Republic of...     29
# Viet Nam                                102
# Yemen                                     1
# Zambia                                    4
# Zimbabwe                                 13
# Name: languageworkedwith, Length: 183, dtype: int64

# %%
country_respondents = df['country'].value_counts()

# %%
python_df = pd.concat([country_respondents, uses_python], axis='columns', sort=False)

# %%
python_df
# Out:
#                   country  languageworkedwith
# United States       12469                5964
# India                8403                2670
# United Kingdom       3896                1621
# Germany              3890                1712
# Canada               2191                1011
# ...                   ...                 ...
# Liechtenstein           1                   0
# Grenada                 1                   0
# Mali                    1                   0
# Marshall Islands        1                   0
# Chad                    1                   0
#
# [183 rows x 2 columns]

# %%
python_df.rename(columns={'country': 'Respondent #', 'languageworkedwith': 'Knows Python' }, inplace=True)

# %%
python_df['% knows Python'] = (python_df['Knows Python']/python_df['Respondent #'])* 100

# %%
python_df.sort_values(by='% knows Python', ascending=False, inplace=True)

# %%
python_df.loc['China']
# Out:
# Respondent #      371.000000
# Knows Python      158.000000
# % knows Python     42.587601
# Name: China, dtype: float64

# %%
import numpy as np

# %%
peoples = {
    'name': ['Paulius','Sniega', 'Grybas', 'Kausas', 'Petras', np.nan, None, 'NA'],
    'last': ['Komskis', 'Komskiene','KEntas', 'Maumas', np.nan, np.nan, 'missing', 'NA'],
    'email': ['sss@one.com', 'www@one.com', 'dddd@one.com', None, np.nan, 'petrukas@xxx.lt', None, np.nan],
    'age': ['33', '44', '55', '11', None, None, np.nan, '67']
}
df_peoples = pd.DataFrame(peoples)
df_peoples.replace('NA', np.nan, inplace=True)
df_peoples.replace('missing', np.nan, inplace=True)
df_peoples
# Out:
#       name       last            email   age
# 0  Paulius    Komskis      sss@one.com    33
# 1   Sniega  Komskiene      www@one.com    44
# 2   Grybas     KEntas     dddd@one.com    55
# 3   Kausas     Maumas             None    11
# 4   Petras        NaN              NaN  None
# 5      NaN        NaN  petrukas@xxx.lt  None
# 6     None        NaN             None   NaN
# 7      NaN        NaN              NaN    67

# %%
df_peoples.dropna()
# Out:
#       name       last         email age
# 0  Paulius    Komskis   sss@one.com  33
# 1   Sniega  Komskiene   www@one.com  44
# 2   Grybas     KEntas  dddd@one.com  55

# %%
df_peoples.dropna(axis='index', how='all', subset=['last','email'])
# Out:
#       name       last            email   age
# 0  Paulius    Komskis      sss@one.com    33
# 1   Sniega  Komskiene      www@one.com    44
# 2   Grybas     KEntas     dddd@one.com    55
# 3   Kausas     Maumas             None    11
# 5      NaN        NaN  petrukas@xxx.lt  None

# %%
df_peoples.isna()
# Out:
#     name   last  email    age
# 0  False  False  False  False
# 1  False  False  False  False
# 2  False  False  False  False
# 3  False  False   True  False
# 4  False   True   True   True
# 5   True   True  False   True
# 6   True   True   True   True
# 7   True   True   True  False

# %%
df_peoples.fillna('0')
# Out:
#       name       last            email age
# 0  Paulius    Komskis      sss@one.com  33
# 1   Sniega  Komskiene      www@one.com  44
# 2   Grybas     KEntas     dddd@one.com  55
# 3   Kausas     Maumas                0  11
# 4   Petras          0                0   0
# 5        0          0  petrukas@xxx.lt   0
# 6        0          0                0   0
# 7        0          0                0  67

# %%
df_peoples['age'] = df_peoples['age'].astype(float)

# %%
df_peoples.dtypes
# Out:
# name      object
# last      object
# email     object
# age      float64
# dtype: object

# %%
df_peoples['age'].median()
# Out:
# 44.0

# %%
df.head()
# Out:
#             age Learned to code at age: compfreq     comptotal  convertedcomp  \
# Respondent
# 62788       NaN                     NaN   Weekly  8.000000e+06      1000000.0
# 65381       NaN                       8   Weekly  8.740000e+09      1000000.0
# 65456       NaN    Younger than 5 years   Weekly  5.521171e+09      1000000.0
# 38672       NaN                       5  Monthly  1.225000e+06       231192.0
# 28374       NaN                       7   Yearly  1.300000e+05       130000.0
#
#                 country          currencydesc currencysymbol  \
# Respondent
# 62788       Afghanistan          Albanian lek            ALL
# 65381       Afghanistan        Afghan afghani            AFN
# 65456       Afghanistan        Afghan afghani            AFN
# 38672       Afghanistan         Russian ruble            RUB
# 28374       Afghanistan  United States dollar            USD
#
#            databasedesirenextyear databaseworkedwith  \
# Respondent
# ...

# %%
df['yearscode'].head(10)
# Out:
# Respondent
# 62788                   NaN
# 65381                    30
# 65456    More than 50 years
# 38672                    40
# 28374                    17
# 9839                     10
# 63848                    14
# 51862                     5
# 51509                     8
# 44484                     8
# Name: yearscode, dtype: object

# %%
df['yearscode'].unique()
# Out:
# array([nan, '30', 'More than 50 years', '40', '17', '10', '14', '5', '8',
#        '9', '4', '6', '3', '2', '35', '1', 'Less than 1 year', '7', '12',
#        '50', '19', '20', '11', '15', '24', '27', '28', '16', '22', '13',
#        '18', '25', '38', '34', '23', '32', '21', '42', '33', '26', '29',
#        '39', '48', '36', '47', '41', '37', '31', '43', '44', '45', '46',
#        '49'], dtype=object)

# %%
df['yearscode'].replace('Less than 1 year', 0, inplace=True)

# %%
df['yearscode'].replace('More than 50 years', 51, inplace=True)

# %%
df['yearscode'] = df['yearscode'].astype(float)

# %%
df['yearscode'].mean()
# Out:
# 12.709052770265584

# %% [markdown]
# ### Working with datetime series

# %%
d_parser = lambda x: pd.datetime.strptime(x, '%Y-%m-%d')
df_eth = pd.read_csv('developer_survey_2020/eth.csv', parse_dates = ['Date'],date_parser=d_parser)
# Out:
# <ipython-input-77-a862cf50c5d1>:1: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   d_parser = lambda x: pd.datetime.strptime(x, '%Y-%m-%d')

# %%
df_eth.head()
# Out:
#   Currency       Date  Closing Price (USD)  24h Open (USD)  24h High (USD)  \
# 0      ETH 2017-07-31           194.967731      202.356029      204.534000
# 1      ETH 2017-08-01           209.020204      194.967731      212.252000
# 2      ETH 2017-08-02           226.213040      209.020204      231.414931
# 3      ETH 2017-08-03           218.789061      226.213040      227.081000
# 4      ETH 2017-08-04           225.307634      218.789061      228.292000
#
#    24h Low (USD)
# 0     190.979107
# 1     189.696378
# 2     205.389557
# 3     215.529025
# 4     218.789061

# %%
df_eth.loc[1, 'Date'].day_name()
# Out:
# 'Tuesday'

# %%
df_eth['Date'].dt.day_name()
# Out:
# 0          Monday
# 1         Tuesday
# 2       Wednesday
# 3        Thursday
# 4          Friday
#           ...
# 1245    Wednesday
# 1246     Thursday
# 1247       Friday
# 1248     Saturday
# 1249       Sunday
# Name: Date, Length: 1250, dtype: object

# %%
df_eth['DayOfWeek'] = df_eth['Date'].dt.day_name()
df_eth.head()
# Out:
#   Currency       Date  Closing Price (USD)  24h Open (USD)  24h High (USD)  \
# 0      ETH 2017-07-31           194.967731      202.356029      204.534000
# 1      ETH 2017-08-01           209.020204      194.967731      212.252000
# 2      ETH 2017-08-02           226.213040      209.020204      231.414931
# 3      ETH 2017-08-03           218.789061      226.213040      227.081000
# 4      ETH 2017-08-04           225.307634      218.789061      228.292000
#
#    24h Low (USD)  DayOfWeek
# 0     190.979107     Monday
# 1     189.696378    Tuesday
# 2     205.389557  Wednesday
# 3     215.529025   Thursday
# 4     218.789061     Friday

# %%
df_eth['Date'].min()
# Out:
# Timestamp('2017-07-31 00:00:00')

# %%
df_eth['Date'].max()
# Out:
# Timestamp('2021-01-10 00:00:00')

# %%
df_eth['Date'].max() - df_eth['Date'].min()
# Out:
# Timedelta('1259 days 00:00:00')

# %%
filt3 = (df_eth['Date'] >= '2020')

# %%
df_eth.loc[filt3]
# Out:
#      Currency       Date  Closing Price (USD)  24h Open (USD)  24h High (USD)  \
# 874       ETH 2020-01-01           129.887363      128.721621      132.679174
# 875       ETH 2020-01-02           127.055601      129.886343      130.632441
# 876       ETH 2020-01-03           132.970833      127.055601      134.684152
# 877       ETH 2020-01-04           133.820621      132.970302      135.584815
# 878       ETH 2020-01-05           134.834252      133.816791      138.195358
# ...       ...        ...                  ...             ...             ...
# 1245      ETH 2021-01-06          1193.571520     1101.903569     1210.541549
# 1246      ETH 2021-01-07          1251.049210     1209.686756     1287.692634
# 1247      ETH 2021-01-08          1208.579979     1223.842565     1273.603079
# 1248      ETH 2021-01-09          1287.484144     1215.225473     1302.222288
# 1249      ETH 2021-01-10          1281.997661     1275.451545     1344.613831
#
#       24h Low (USD)  DayOfWeek
# ...

# %%
filt3 = (df_eth['Date'] >= '2017') & (df_eth['Date'] < '2020')
df_eth.loc[filt3]
# Out:
#     Currency       Date  Closing Price (USD)  24h Open (USD)  24h High (USD)  \
# 0        ETH 2017-07-31           194.967731      202.356029      204.534000
# 1        ETH 2017-08-01           209.020204      194.967731      212.252000
# 2        ETH 2017-08-02           226.213040      209.020204      231.414931
# 3        ETH 2017-08-03           218.789061      226.213040      227.081000
# 4        ETH 2017-08-04           225.307634      218.789061      228.292000
# ..       ...        ...                  ...             ...             ...
# 869      ETH 2019-12-27           126.149214      125.256345      126.663883
# 870      ETH 2019-12-28           128.011145      126.149377      129.374125
# 871      ETH 2019-12-29           134.768035      128.011380      137.806279
# 872      ETH 2019-12-30           132.073074      134.279097      136.011570
# 873      ETH 2019-12-31           128.722604      132.126527      133.405184
#
#      24h Low (USD)  DayOfWeek
# ...

# %%
filt3 = (df_eth['Date'] >= pd.to_datetime('2017-01-13')) & (df_eth['Date'] < pd.to_datetime(
'2020-01-01'))
df_eth.loc[filt3]
# Out:
#     Currency       Date  Closing Price (USD)  24h Open (USD)  24h High (USD)  \
# 0        ETH 2017-07-31           194.967731      202.356029      204.534000
# 1        ETH 2017-08-01           209.020204      194.967731      212.252000
# 2        ETH 2017-08-02           226.213040      209.020204      231.414931
# 3        ETH 2017-08-03           218.789061      226.213040      227.081000
# 4        ETH 2017-08-04           225.307634      218.789061      228.292000
# ..       ...        ...                  ...             ...             ...
# 869      ETH 2019-12-27           126.149214      125.256345      126.663883
# 870      ETH 2019-12-28           128.011145      126.149377      129.374125
# 871      ETH 2019-12-29           134.768035      128.011380      137.806279
# 872      ETH 2019-12-30           132.073074      134.279097      136.011570
# 873      ETH 2019-12-31           128.722604      132.126527      133.405184
#
#      24h Low (USD)  DayOfWeek
# ...

# %%
df_eth.set_index('Date', inplace=True)

# %%
df_eth
# Out:
#            Currency  Closing Price (USD)  24h Open (USD)  24h High (USD)  \
# Date
# 2017-07-31      ETH           194.967731      202.356029      204.534000
# 2017-08-01      ETH           209.020204      194.967731      212.252000
# 2017-08-02      ETH           226.213040      209.020204      231.414931
# 2017-08-03      ETH           218.789061      226.213040      227.081000
# 2017-08-04      ETH           225.307634      218.789061      228.292000
# ...             ...                  ...             ...             ...
# 2021-01-06      ETH          1193.571520     1101.903569     1210.541549
# 2021-01-07      ETH          1251.049210     1209.686756     1287.692634
# 2021-01-08      ETH          1208.579979     1223.842565     1273.603079
# 2021-01-09      ETH          1287.484144     1215.225473     1302.222288
# 2021-01-10      ETH          1281.997661     1275.451545     1344.613831
#
#             24h Low (USD)  DayOfWeek
# Date
# 2017-07-31     190.979107     Monday
# ...

# %%
df_eth['2018']
# Out:
# <ipython-input-91-320a75d6eaba>:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   df_eth['2018']
#            Currency  Closing Price (USD)  24h Open (USD)  24h High (USD)  \
# Date
# 2018-01-01      ETH           865.012000      762.258000      914.830000
# 2018-01-02      ETH           884.858000      857.346000      911.367000
# 2018-01-03      ETH           947.321000      884.825000      974.471000
# 2018-01-04      ETH          1038.380000      949.291000     1058.520000
# 2018-01-05      ETH          1012.870000     1049.060000     1075.390000
# ...             ...                  ...             ...             ...
# 2018-12-25      ETH           128.632904      139.046768      139.866593
# 2018-12-26      ETH           130.706663      128.647892      136.326377
# ...

# %%
df_eth['2017-03' : '2020-01']['Closing Price (USD)']
# Out:
# Date
# 2017-07-31    194.967731
# 2017-08-01    209.020204
# 2017-08-02    226.213040
# 2017-08-03    218.789061
# 2017-08-04    225.307634
#                  ...
# 2020-01-27    169.800113
# 2020-01-28    173.548148
# 2020-01-29    175.460322
# 2020-01-30    186.262041
# 2020-01-31    181.728434
# Name: Closing Price (USD), Length: 905, dtype: float64

# %%
df_eth['2017-03' : '2020-01']['Closing Price (USD)'].mean()
# Out:
# 332.52039211191936

# %%
df_eth['2018-01']['24h High (USD)'].max()
# Out:
# <ipython-input-94-a8450553b731>:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   df_eth['2018-01']['24h High (USD)'].max()
# 1432.88

# %%
high = df_eth['24h High (USD)'].resample('W').max()
high['2020-01']
# Out:
# Date
# 2020-01-05    138.195358
# 2020-01-12    147.887859
# 2020-01-19    179.161116
# 2020-01-26    171.161213
# Freq: W-SUN, Name: 24h High (USD), dtype: float64

# %%
# %matplotlib inline

# %%
high.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df_eth.resample('W').mean()
# Out:
#             Closing Price (USD)  24h Open (USD)  24h High (USD)  24h Low (USD)
# Date
# 2017-08-06           222.845285      214.804880      228.907419     209.452553
# 2017-08-13           294.308751      288.432891      303.987279     274.494509
# 2017-08-20           297.024479      296.954293      305.397916     285.194501
# 2017-08-27           329.388075      321.436200      335.904548     315.485305
# 2017-09-03           366.998945      367.668660      378.989535     351.113834
# ...                         ...             ...             ...            ...
# 2020-12-13           571.729642      570.566197      583.081843     552.637578
# 2020-12-20           629.185740      622.707038      642.041391     608.617945
# 2020-12-27           624.943603      620.466326      647.484215     592.472114
# 2021-01-03           773.752154      733.466895      788.908870     716.484043
# 2021-01-10          1194.815393     1148.464090     1242.373363    1070.491212
#
# ...

# %%
df_eth.resample('W').agg({'Closing Price (USD)': 'mean',
                         '24h High (USD)': 'max',
                         '24h Low (USD)': 'min'})
# Out:
#             Closing Price (USD)  24h High (USD)  24h Low (USD)
# Date
# 2017-08-06           222.845285      270.328000     189.696378
# 2017-08-13           294.308751      318.716000     251.885531
# 2017-08-20           297.024479      310.640425     269.319992
# 2017-08-27           329.388075      350.382989     290.289161
# 2017-09-03           366.998945      394.322096     326.200376
# ...                         ...             ...            ...
# 2020-12-13           571.729642      603.417174     530.242646
# 2020-12-20           629.185740      676.203179     575.829119
# 2020-12-27           624.943603      714.112544     552.040076
# 2021-01-03           773.752154      989.551795     680.206472
# 2021-01-10          1194.815393     1344.613831     890.473806
#
# [180 rows x 3 columns]

# %%
filt4 = (df['country'] == 'India')
india_df = df.loc[filt4]
india_df.head(2)
# Out:
#             age Learned to code at age: compfreq  comptotal  convertedcomp  \
# Respondent
# 37655       NaN                      15  Monthly   150000.0      1800000.0
# 36976       NaN                      20   Yearly  1600000.0      1600000.0
#
#            country          currencydesc currencysymbol  \
# Respondent
# 37655        India  United States dollar            USD
# 36976        India  United States dollar            USD
#
#            databasedesirenextyear             databaseworkedwith  \
# Respondent
# 37655                    Firebase  Firebase;Microsoft SQL Server
# 36976                         NaN                            NaN
#
#                                                       devtype  \
# Respondent
# 37655       Developer, front-end;Developer, full-stack;Dev...
# 36976       Data or business analyst;Database administrato...
#
#                                                     edlevel  \
# Respondent
# ...

# %% [markdown]
# ### Reading /writting

# %%
india_df.to_csv('developer_survey_2020/sample-india.csv')

# %%
india_df.to_csv('developer_survey_2020/sample-india.tsv', sep='\t')

# %%
india_df.to_excel('developer_survey_2020/sample-india.xlsx')

# %%
test = pd.read_excel('developer_survey_2020/sample-india.xlsx', index_col='Respondent')

# %%
test.head()
# Out:
#              age Learned to code at age: compfreq     comptotal  \
# Respondent
# 37655        NaN                      15  Monthly  1.500000e+05
# 36976        NaN                      20   Yearly  1.600000e+06
# 3332         NaN                      19  Monthly  4.200000e+07
# 8457        22.0                      18  Monthly  7.000000e+06
# 21351       98.0                      17   Weekly  8.988829e+30
#
#             convertedcomp country          currencydesc currencysymbol  \
# Respondent
# 37655           1800000.0   India  United States dollar            USD
# 36976           1600000.0   India  United States dollar            USD
# 3332            1000000.0   India          Indian rupee            INR
# 8457            1000000.0   India          Indian rupee            INR
# 21351           1000000.0   India         European Euro            EUR
#
#                                        databasedesirenextyear  \
# Respondent
# ...

# %%
india_df.to_json('developer_survey_2020/sample-india.json', orient='records', lines=True)

# %%
test = pd.read_json('developer_survey_2020/sample-india.json', orient='records', lines=True)

# %%
test
# Out:
#        age Learned to code at age: compfreq     comptotal  convertedcomp  \
# 0      NaN                      15  Monthly  1.500000e+05      1800000.0
# 1      NaN                      20   Yearly  1.600000e+06      1600000.0
# 2      NaN                      19  Monthly  4.200000e+07      1000000.0
# 3     22.0                      18  Monthly  7.000000e+06      1000000.0
# 4     98.0                      17   Weekly  8.988829e+30      1000000.0
# ...    ...                     ...      ...           ...            ...
# 8398   NaN                      18     None           NaN            NaN
# 8399   NaN                    None     None           NaN            NaN
# 8400   NaN                    None     None           NaN            NaN
# 8401   NaN                    None     None           NaN            NaN
# 8402   NaN                    None     None           NaN            NaN
#
#      country          currencydesc currencysymbol  \
# ...

# %%
df.dtypes
# Out:
# age                             float64
# Learned to code at age:          object
# compfreq                         object
# comptotal                       float64
# convertedcomp                   float64
# country                          object
# currencydesc                     object
# currencysymbol                   object
# databasedesirenextyear           object
# databaseworkedwith               object
# devtype                          object
# edlevel                          object
# employment                       object
# ethnicity                        object
# gender                           object
# jobfactors                       object
# jobsat                           object
# jobseek                          object
# languagedesirenextyear           object
# languageworkedwith               object
# misctechdesirenextyear           object
# misctechworkedwith               object
# newcollabtoolsdesirenextyear     object
# ...

# %%
df['yearscodepro'].replace(['More than 50 years'], '51', inplace=True)
df['yearscodepro'].replace(['Less than 1 year'], '1', inplace=True)

# %%
df['yearscodepro'].unique
# Out:
# <bound method Series.unique of Respondent
# 62788    NaN
# 65381     35
# 65456     51
# 38672     40
# 28374      5
#         ...
# 60055    NaN
# 61121    NaN
# 61570    NaN
# 61918    NaN
# 62605    NaN
# Name: yearscodepro, Length: 64461, dtype: object>

# %%
filt_proyears = df['yearscodepro'].astype('float').mean(axis=0)

# %%
df['yearscodepro'].replace(np.nan, filt_proyears, inplace=True)

# %%
df['yearscodepro']
# Out:
# Respondent
# 62788    8.538717
# 65381          35
# 65456          51
# 38672          40
# 28374           5
#            ...
# 60055    8.538717
# 61121    8.538717
# 61570    8.538717
# 61918    8.538717
# 62605    8.538717
# Name: yearscodepro, Length: 64461, dtype: object

# %%
df['yearscodepro'].unique
# Out:
# <bound method Series.unique of Respondent
# 62788    8.538717
# 65381          35
# 65456          51
# 38672          40
# 28374           5
#            ...
# 60055    8.538717
# 61121    8.538717
# 61570    8.538717
# 61918    8.538717
# 62605    8.538717
# Name: yearscodepro, Length: 64461, dtype: object>

# %%
df.isnull().sum()
# Out:
# age                             19013
# Learned to code at age:          6561
# compfreq                        24392
# comptotal                       29635
# convertedcomp                   29705
# country                           389
# currencydesc                    18989
# currencysymbol                  17996
# databasedesirenextyear          20391
# databaseworkedwith              14924
# devtype                         15091
# edlevel                          7030
# employment                        607
# ethnicity                       18513
# gender                          13904
# jobfactors                      15112
# jobsat                          19267
# jobseek                         12734
# languagedesirenextyear          10348
# languageworkedwith               7083
# misctechdesirenextyear          22082
# misctechworkedwith              24147
# newcollabtoolsdesirenextyear    17174
# newcollabtoolsworkedwith        11578
# newdevops                       21775
# ...

# %%
df.isnull().sum()
# Out:
# age                             19013
# Learned to code at age:          6561
# compfreq                        24392
# comptotal                       29635
# convertedcomp                   29705
# country                           389
# currencydesc                    18989
# currencysymbol                  17996
# databasedesirenextyear          20391
# databaseworkedwith              14924
# devtype                         15091
# edlevel                          7030
# employment                        607
# ethnicity                       18513
# gender                          13904
# jobfactors                      15112
# jobsat                          19267
# jobseek                         12734
# languagedesirenextyear          10348
# languageworkedwith               7083
# misctechdesirenextyear          22082
# misctechworkedwith              24147
# newcollabtoolsdesirenextyear    17174
# newcollabtoolsworkedwith        11578
# newdevops                       21775
# ...

# %%
df.head(3)
# Out:
#             age Learned to code at age: compfreq     comptotal  convertedcomp  \
# Respondent
# 62788       NaN                     NaN   Weekly  8.000000e+06      1000000.0
# 65381       NaN                       8   Weekly  8.740000e+09      1000000.0
# 65456       NaN    Younger than 5 years   Weekly  5.521171e+09      1000000.0
#
#                 country    currencydesc currencysymbol databasedesirenextyear  \
# Respondent
# 62788       Afghanistan    Albanian lek            ALL                    NaN
# 65381       Afghanistan  Afghan afghani            AFN                    NaN
# 65456       Afghanistan  Afghan afghani            AFN                    NaN
#
#            databaseworkedwith  \
# Respondent
# 62788                     NaN
# 65381                     NaN
# 65456                     NaN
#
#                                                       devtype  \
# Respondent
# 62788                                               Scientist
# ...
